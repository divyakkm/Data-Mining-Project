# %%
from __future__ import division
import pickle
import sklearn
from sklearn.naive_bayes import *
import pandas as pd
import numpy as np
from sklearn import *
import os
from sklearn.metrics import *
from sklearn import metrics, preprocessing
from sklearn import svm, naive_bayes, neighbors, tree
from sklearn.ensemble import AdaBoostClassifier


def createPickle(data, filename):
    with open(filename, 'wb') as f:
            pickle.dump(data, f)
    print "Pickled", filename


# Setting up constants
print "Setting constants..."

TRAINING_LINE_NUMBER = 10000
# YEARS = ['2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008']
# YEARS = ['2008', '2006', '2007']
# INPUT_FILE_PATH = "/home/dmenghani/python/"  # Unix path
INPUT_FILE_PATH = "C:\\data\\airline\\"  # Windows path
YEARS = ['2008']
SKIP_FIRST_LINE = True  # To skip the first line, as its the header

master = []
print "Reading into Pandas frame..."
try:
    for year in YEARS:
        path = os.path.join(INPUT_FILE_PATH, '%d.csv' % int(year))
        print "\n", path
        dfPart = pd.read_csv(
            path, nrows=TRAINING_LINE_NUMBER, skiprows=0, usecols=[
                u'Year',
                u'Month',
                u'DayofMonth',
                u'DayOfWeek',
                u'UniqueCarrier',
                u'DepTime',
                u'TailNum',
                u'Origin',
                u'Dest',
                u'DepDelay',
                # u'ArrDelay',
                u'Cancelled',
                #                 u'ArrTime',
                #                 u'ArrDelay',
                #                 u'Distance'
            ])
        print len(dfPart)
        dfPart = dfPart[dfPart['Cancelled'] == 0]
        # dfPart['Year'] = year
        # rows = np.random.choice(
        #     np.random.permutation(dfPart.index.values), len(dfPart) // 1, replace=False)
        # print rows
        # sampled_dfPart = dfPart.ix[rows]
        sampled_dfPart = dfPart
        print "Removed cancelled flights, new length - ", len(sampled_dfPart)
        master.append(sampled_dfPart)
        print
except Exception as e:
    print "Supplemental Data Import failed", e

dfMaster = pd.concat(master, ignore_index=True)
master = []
dfPart = []

print "Total length - ", len(dfMaster)
del dfMaster['Cancelled']

dfMaster.fillna(0, inplace=True)
dfMaster['Year'] = dfMaster['Year'].astype('int')
dfMaster['Month'] = dfMaster['Month'].astype('int')
dfMaster['DayofMonth'] = dfMaster['DayofMonth'].astype('int')
dfMaster['DayOfWeek'] = dfMaster['DayOfWeek'].astype('int')
dfMaster['DepTime'] = dfMaster['DepTime'].astype('int')
dfMaster['DepDelay'] = dfMaster['DepDelay'].astype('int')

df = dfMaster

print "Calculating classification label..."
df['label'] = 0
df.label[df.DepDelay >= 1] = 1
df.label[df.DepDelay < 1] = 0
print "Actual delayed flights  -", np.sum(dfMaster['label']) / len(dfMaster['label'])

# df['DepDelay'][df.DepDelay < 0] = 0
del df['DepDelay']
# df['ArrDelay'][df.ArrDelay < 0] = 0

print "Dataframe shape - ", df.shape
print "Columns -", df.columns


# In[136]:

print "Converting categorical data to numeric..."
for col in set(df.columns):
# print col, train[col].dtype
    if df[col].dtype == np.dtype('object'):
        print "Converting...", col
        if col == 'TailNum':
            s = np.unique(df[col].values)
            TailNum = pd.Series([x[0] for x in enumerate(s)], index=s)
#             print TailNum
        if col == 'UniqueCarrier':
            s = np.unique(df[col].values)
            UniqueCarrier = pd.Series([x[0] for x in enumerate(s)], index=s)
#             print UniqueCarrier
        if col == 'Dest':
            s = np.unique(df[col].values)
            Dest = pd.Series([x[0] for x in enumerate(s)], index=s)
            # print Dest
        if col == 'Origin':
            s = np.unique(df[col].values)
            Origin = pd.Series([x[0] for x in enumerate(s)], index=s)
            # print Origin

# print "sfo,", Origin['SFO']
# print "oak,", Origin['OAK']

# createPickle(Dest, 'Dest_2008.pkl')
# createPickle(Origin, 'Origin_2008.pkl')
# createPickle(UniqueCarrier, 'UniqueCarrier_2008.pkl')
# createPickle(TailNum, 'TailNum_2008.pkl')

print "Pickle completed."


def getTailNum(inTailNum):
#     print "In...",type(inTailNum)
    out = []
    for x, y in inTailNum.iteritems():
#         print "x,y, out",x,y,TailNum.get_value(y)
        out.append(TailNum.get_value(y) + 1)
#     print "final out", out
    return out


def getDest(inDest):
    out = []
    for x, y in inDest.iteritems():
        out.append(Dest.get_value(y) + 1)
    return out


def getOrigin(inOrign):
    out = []
#     print inOrign
    for x, y in inOrign.iteritems():
        out.append(Origin.get_value(y) + 1)
    return out


def getCarrier(inCarrier):
    out = []
    for x, y in inCarrier.iteritems():
        out.append(UniqueCarrier.get_value(y) + 1)
    return out

# print "Before conversion..."
# print len(dfMaster[dfMaster['Origin'] == 'SFO'])
# print len(dfMaster[dfMaster['Origin'] == 'OAK'])
df[df['Origin'] == 'SFO']
# Out:
# Setting constants...
# Reading into Pandas frame...
#
# C:\data\airline\2008.csv
# 10000
# Removed cancelled flights, new length -  9837
#
# Total length -  9837
# Calculating classification label...
# Actual delayed flights  - 0.756429805835
# Dataframe shape -  (9837, 10)
# Columns - Index([u'Year', u'Month', u'DayofMonth', u'DayOfWeek', u'DepTime', u'UniqueCarrier', u'TailNum', u'Origin', u'Dest', u'label'], dtype='object')
# Converting categorical data to numeric...
# Converting... Origin
# Converting... UniqueCarrier
# Converting... Dest
# Converting... TailNum
# Pickle completed.
#       Year  Month  DayofMonth  DayOfWeek  DepTime UniqueCarrier TailNum  \
# 1863  2008      1           3          4     2036            WN  N203WN
# 1864  2008      1           3          4      708            WN  N756SA
# 1865  2008      1           3          4     1254            WN  N491WN
# 1866  2008      1           3          4     1516            WN  N245WN
# 1867  2008      1           3          4      844            WN  N435WN
# 1868  2008      1           3          4     2059            WN  N761RR
# 1869  2008      1           3          4     2225            WN  N602SW
# 1870  2008      1           3          4     1800            WN  N901WN
# 1871  2008      1           3          4      852            WN  N738CB
# 1872  2008      1           3          4     1053            WN  N486WN
# 1873  2008      1           3          4     1801            WN  N738CB
# 1874  2008      1           3          4     1447            WN  N738CB
# 1875  2008      1           3          4     2155            WN  N738CB
# 1876  2008      1           3          4     1657            WN  N751SW
# 1877  2008      1           3          4     1911            WN  N287WN
# 1878  2008      1           3          4      703            WN  N433LV
# 1879  2008      1           3          4     1221            WN  N797MX
# 1880  2008      1           3          4      803            WN  N246LV
# 1881  2008      1           3          4      619            WN  N324SW
# 1882  2008      1           3          4     1324            WN  N429WN
# 1883  2008      1           3          4     2325            WN  N302SW
# 1884  2008      1           3          4     1711            WN  N492WN
# 1885  2008      1           3          4     1636            WN  N615SW
# 1886  2008      1           3          4     2303            WN  N421LV
# 5235  2008      1           4          5     1957            WN  N268WN
# 5236  2008      1           4          5      629            WN  N398SW
# 5237  2008      1           4          5     1727            WN  N672SW
# 5238  2008      1           4          5      905            WN  N770SA
# 5239  2008      1           4          5     1914            WN  N478WN
# 5240  2008      1           4          5     1946            WN  N901WN
# 5241  2008      1           4          5      922            WN  N284WN
# 5242  2008      1           4          5     1734            WN  N284WN
# 5243  2008      1           4          5     2133            WN  N284WN
# 5244  2008      1           4          5     1447            WN  N901WN
# 5245  2008      1           4          5     1531            WN  N491WN
# 5246  2008      1           4          5     1755            WN  N752SW
# 5247  2008      1           4          5      707            WN  N478WN
# 5248  2008      1           4          5     1142            WN  N343SW
# 5249  2008      1           4          5      813            WN  N490WN
# 5250  2008      1           4          5      618            WN  N447WN
# 5251  2008      1           4          5     1326            WN  N403WN
# 5252  2008      1           4          5     2046            WN  N611SW
# 5253  2008      1           4          5     1708            WN  N749SW
# 5254  2008      1           4          5     1716            WN  N359SW
# 5255  2008      1           4          5     2110            WN  N701GS
# 8085  2008      1           5          6     2210            WN  N213WN
# 8086  2008      1           5          6     1213            WN  N735SA
# 8087  2008      1           5          6      742            WN  N251WN
# 8088  2008      1           5          6     1822            WN  N429WN
# 8089  2008      1           5          6     2129            WN  N408WN
# 8090  2008      1           5          6     2155            WN  N901WN
# 8091  2008      1           5          6      915            WN  N297WN
# 8092  2008      1           5          6     1109            WN  N901WN
# 8093  2008      1           5          6     1908            WN  N283WN
# 8094  2008      1           5          6      713            WN  N901WN
# 8095  2008      1           5          6     1755            WN  N901WN
# 8096  2008      1           5          6     1546            WN  N727SW
# 8097  2008      1           5          6      710            WN  N710SW
# 8098  2008      1           5          6     1745            WN  N618WN
# 8099  2008      1           5          6     1153            WN  N369SW
#        ...    ...         ...        ...      ...           ...     ...
#
#      Origin Dest  label
# 1863    SFO  LAS      1
# 1864    SFO  LAS      1
# 1865    SFO  LAS      1
# 1866    SFO  LAS      1
# 1867    SFO  LAS      0
# 1868    SFO  LAS      1
# 1869    SFO  LAS      1
# 1870    SFO  LAX      0
# 1871    SFO  LAX      1
# 1872    SFO  LAX      1
# 1873    SFO  LAX      1
# 1874    SFO  LAX      1
# 1875    SFO  LAX      1
# 1876    SFO  MDW      1
# 1877    SFO  MDW      1
# 1878    SFO  MDW      0
# 1879    SFO  SAN      1
# 1880    SFO  SAN      0
# 1881    SFO  SAN      0
# 1882    SFO  SAN      1
# 1883    SFO  SAN      1
# 1884    SFO  SAN      1
# 1885    SFO  SAN      1
# 1886    SFO  SAN      1
# 5235    SFO  LAS      1
# 5236    SFO  LAS      0
# 5237    SFO  LAS      1
# 5238    SFO  LAS      1
# 5239    SFO  LAS      1
# 5240    SFO  LAX      1
# 5241    SFO  LAX      1
# 5242    SFO  LAX      1
# 5243    SFO  LAX      1
# 5244    SFO  LAX      1
# 5245    SFO  MDW      1
# 5246    SFO  MDW      1
# 5247    SFO  MDW      1
# 5248    SFO  SAN      1
# 5249    SFO  SAN      1
# 5250    SFO  SAN      0
# 5251    SFO  SAN      1
# 5252    SFO  SAN      1
# 5253    SFO  SAN      1
# 5254    SFO  SAN      1
# 5255    SFO  SAN      0
# 8085    SFO  LAS      1
# 8086    SFO  LAS      1
# 8087    SFO  LAS      1
# 8088    SFO  LAS      1
# 8089    SFO  LAS      1
# 8090    SFO  LAX      1
# 8091    SFO  LAX      1
# 8092    SFO  LAX      1
# 8093    SFO  LAX      1
# 8094    SFO  LAX      1
# 8095    SFO  LAX      1
# 8096    SFO  MDW      1
# 8097    SFO  MDW      1
# 8098    SFO  MDW      1
# 8099    SFO  SAN      1
#         ...  ...    ...
#
# [64 rows x 10 columns]

# %%
df['TailNum'] = getTailNum(df['TailNum'])
df['UniqueCarrier'] = getCarrier(df['UniqueCarrier'])
df['Dest'] = getDest(df['Dest'])
df['Origin'] =getOrigin(df['Origin'])

# print "TailNum completed."
# print "UniqueCarrier completed."
# print "Dest completed."
# print "Origin completed."

# print "Conversion to numeric completed."

# print "After conversion..."
# dfSFO = df[df['Origin'].isin([Origin['SFO']])]
# print "SFO len - ", len(dfSFO)
# print Dest[np.unique(dfSFO['Dest'])]

# dfOAK = df[df['Origin'].isin([Origin['OAK']])]
# print "OAK len - ", len(dfOAK)
# print Dest[np.unique(dfOAK['Dest'])]
print Origin+1
print Dest+1
df[df['Origin'] == 'SFO']
# Out:
# ABQ     1
# ALB     2
# AMA     3
# AUS     4
# BDL     5
# BHM     6
# BNA     7
# BOI     8
# BUF     9
# BUR    10
# BWI    11
# CLE    12
# CMH    13
# CRP    14
# DAL    15
# ...
# RNO    50
# RSW    51
# SAN    52
# SAT    53
# SDF    54
# SEA    55
# SFO    56
# SJC    57
# SLC    58
# SMF    59
# SNA    60
# STL    61
# TPA    62
# TUL    63
# TUS    64
# Length: 64, dtype: int64
# ABQ     1
# ALB     2
# AMA     3
# AUS     4
# BDL     5
# BHM     6
# BNA     7
# BOI     8
# BUF     9
# BUR    10
# BWI    11
# CLE    12
# CMH    13
# CRP    14
# DAL    15
# ...
# RNO    50
# RSW    51
# SAN    52
# SAT    53
# SDF    54
# SEA    55
# SFO    56
# SJC    57
# SLC    58
# SMF    59
# SNA    60
# STL    61
# TPA    62
# TUL    63
# TUS    64
# Length: 64, dtype: int64
#       Year  Month  DayofMonth  DayOfWeek  DepTime UniqueCarrier TailNum  \
# 1863  2008      1           3          4     2036            WN  N203WN
# 1864  2008      1           3          4      708            WN  N756SA
# 1865  2008      1           3          4     1254            WN  N491WN
# 1866  2008      1           3          4     1516            WN  N245WN
# 1867  2008      1           3          4      844            WN  N435WN
# 1868  2008      1           3          4     2059            WN  N761RR
# 1869  2008      1           3          4     2225            WN  N602SW
# 1870  2008      1           3          4     1800            WN  N901WN
# 1871  2008      1           3          4      852            WN  N738CB
# 1872  2008      1           3          4     1053            WN  N486WN
# 1873  2008      1           3          4     1801            WN  N738CB
# 1874  2008      1           3          4     1447            WN  N738CB
# 1875  2008      1           3          4     2155            WN  N738CB
# 1876  2008      1           3          4     1657            WN  N751SW
# 1877  2008      1           3          4     1911            WN  N287WN
# 1878  2008      1           3          4      703            WN  N433LV
# 1879  2008      1           3          4     1221            WN  N797MX
# 1880  2008      1           3          4      803            WN  N246LV
# 1881  2008      1           3          4      619            WN  N324SW
# 1882  2008      1           3          4     1324            WN  N429WN
# 1883  2008      1           3          4     2325            WN  N302SW
# 1884  2008      1           3          4     1711            WN  N492WN
# 1885  2008      1           3          4     1636            WN  N615SW
# 1886  2008      1           3          4     2303            WN  N421LV
# 5235  2008      1           4          5     1957            WN  N268WN
# 5236  2008      1           4          5      629            WN  N398SW
# 5237  2008      1           4          5     1727            WN  N672SW
# 5238  2008      1           4          5      905            WN  N770SA
# 5239  2008      1           4          5     1914            WN  N478WN
# 5240  2008      1           4          5     1946            WN  N901WN
# 5241  2008      1           4          5      922            WN  N284WN
# 5242  2008      1           4          5     1734            WN  N284WN
# 5243  2008      1           4          5     2133            WN  N284WN
# 5244  2008      1           4          5     1447            WN  N901WN
# 5245  2008      1           4          5     1531            WN  N491WN
# 5246  2008      1           4          5     1755            WN  N752SW
# 5247  2008      1           4          5      707            WN  N478WN
# 5248  2008      1           4          5     1142            WN  N343SW
# 5249  2008      1           4          5      813            WN  N490WN
# 5250  2008      1           4          5      618            WN  N447WN
# 5251  2008      1           4          5     1326            WN  N403WN
# 5252  2008      1           4          5     2046            WN  N611SW
# 5253  2008      1           4          5     1708            WN  N749SW
# 5254  2008      1           4          5     1716            WN  N359SW
# 5255  2008      1           4          5     2110            WN  N701GS
# 8085  2008      1           5          6     2210            WN  N213WN
# 8086  2008      1           5          6     1213            WN  N735SA
# 8087  2008      1           5          6      742            WN  N251WN
# 8088  2008      1           5          6     1822            WN  N429WN
# 8089  2008      1           5          6     2129            WN  N408WN
# 8090  2008      1           5          6     2155            WN  N901WN
# 8091  2008      1           5          6      915            WN  N297WN
# 8092  2008      1           5          6     1109            WN  N901WN
# 8093  2008      1           5          6     1908            WN  N283WN
# 8094  2008      1           5          6      713            WN  N901WN
# 8095  2008      1           5          6     1755            WN  N901WN
# 8096  2008      1           5          6     1546            WN  N727SW
# 8097  2008      1           5          6      710            WN  N710SW
# 8098  2008      1           5          6     1745            WN  N618WN
# 8099  2008      1           5          6     1153            WN  N369SW
#        ...    ...         ...        ...      ...           ...     ...
#
#      Origin Dest  label  Dest_new  Origin_new
# 1863    SFO  LAS      1        28          56
# 1864    SFO  LAS      1        28          56
# 1865    SFO  LAS      1        28          56
# 1866    SFO  LAS      1        28          56
# 1867    SFO  LAS      0        28          56
# 1868    SFO  LAS      1        28          56
# 1869    SFO  LAS      1        28          56
# 1870    SFO  LAX      0        29          56
# 1871    SFO  LAX      1        29          56
# 1872    SFO  LAX      1        29          56
# 1873    SFO  LAX      1        29          56
# 1874    SFO  LAX      1        29          56
# 1875    SFO  LAX      1        29          56
# 1876    SFO  MDW      1        35          56
# 1877    SFO  MDW      1        35          56
# 1878    SFO  MDW      0        35          56
# 1879    SFO  SAN      1        52          56
# 1880    SFO  SAN      0        52          56
# 1881    SFO  SAN      0        52          56
# 1882    SFO  SAN      1        52          56
# 1883    SFO  SAN      1        52          56
# 1884    SFO  SAN      1        52          56
# 1885    SFO  SAN      1        52          56
# 1886    SFO  SAN      1        52          56
# 5235    SFO  LAS      1        28          56
# 5236    SFO  LAS      0        28          56
# 5237    SFO  LAS      1        28          56
# 5238    SFO  LAS      1        28          56
# 5239    SFO  LAS      1        28          56
# 5240    SFO  LAX      1        29          56
# 5241    SFO  LAX      1        29          56
# 5242    SFO  LAX      1        29          56
# 5243    SFO  LAX      1        29          56
# 5244    SFO  LAX      1        29          56
# 5245    SFO  MDW      1        35          56
# 5246    SFO  MDW      1        35          56
# 5247    SFO  MDW      1        35          56
# 5248    SFO  SAN      1        52          56
# 5249    SFO  SAN      1        52          56
# 5250    SFO  SAN      0        52          56
# 5251    SFO  SAN      1        52          56
# 5252    SFO  SAN      1        52          56
# 5253    SFO  SAN      1        52          56
# 5254    SFO  SAN      1        52          56
# 5255    SFO  SAN      0        52          56
# 8085    SFO  LAS      1        28          56
# 8086    SFO  LAS      1        28          56
# 8087    SFO  LAS      1        28          56
# 8088    SFO  LAS      1        28          56
# 8089    SFO  LAS      1        28          56
# 8090    SFO  LAX      1        29          56
# 8091    SFO  LAX      1        29          56
# 8092    SFO  LAX      1        29          56
# 8093    SFO  LAX      1        29          56
# 8094    SFO  LAX      1        29          56
# 8095    SFO  LAX      1        29          56
# 8096    SFO  MDW      1        35          56
# 8097    SFO  MDW      1        35          56
# 8098    SFO  MDW      1        35          56
# 8099    SFO  SAN      1        52          56
#         ...  ...    ...       ...         ...
#
# [64 rows x 12 columns]

# %%
# print "Begin cross validation..."

# features = df.columns[0:9]
# target_names = ['Not Delayed', 'Delayed']
# accuracy = {}
# results = {}
# matrix = {}
# prec = {}
# recall = {}

# for year in YEARS:
#     print "Testing on - ", year
#     train = df[df['Year'] != int(year)]
#     test = df[df['Year'] == int(year)]
#     test = test[test['Origin'].isin([Origin['OAK'], Origin['SFO']])]
#     print len(train), len(test)
#     # rows = np.random.choice(np.random.permutation(
#     #     test.index.values), len(test) // 1, replace=False)
#     # print rows
#     # sampled_test = test.ix[rows]
#     sampled_test = test
#     trainTargets = np.array(train['label']).astype(int)
#     testTargets = np.array(sampled_test['label']).astype(int)
#     print "Train length - ", len(train), "Test length -  ", len(sampled_test)
# #     print train['Year']
# #     print test['Year']
#     print "Model fitting and prediction started..."
#     gnb = GaussianNB()
#     y_gnb = gnb.fit(train[features], trainTargets).predict(
#         sampled_test[features])
#     sampled_test['pred_label'] = y_gnb
#     # y_prob = gnb.fit(
#     #     train[features], trainTargets).predict_proba(test[features])
#     # print y_prob
#     # test['pred_prob'] = y_prob[1][1]
#     print "Classification completed."
#     createPickle(gnb, INPUT_FILE_PATH + "classifier_" + year + ".pkl")
#     createPickle(y_gnb, INPUT_FILE_PATH + "label_" + year + ".pkl")
#     sampled_test.to_csv(
#         INPUT_FILE_PATH + "\dfTest" + year + ".csv", index=False)

#     print "\nCalculating metrcs..."
#     accuracy[int(year)] = accuracy_score(sampled_test['label'], y_gnb)
#     print "Accuracy score - ", accuracy[int(year)]
#     prec[int(year)] = precision_score(
#         sampled_test['label'], y_gnb, average='micro')
#     print "Precision Score - ", prec[int(year)]
#     recall[int(year)] = recall_score(
#         sampled_test['label'], y_gnb, average='micro')
#     print "Recall Score - ", recall[int(year)]
#     print "Confusion matrix"
#     matrix[int(year)] = metrics.confusion_matrix(
#         sampled_test['label'], y_gnb)
#     print matrix[int(year)]
#     results[int(year)] = precision_recall_fscore_support(
#         sampled_test['label'], y_gnb, average='micro')
#     print "Precision, recall, F-Score, Support - ", results[int(year)]
#     print "Classification report"
#     print classification_report(np.array(sampled_test['label']), y_gnb,
#                                 target_names=target_names)
#     print
#     train = []
#     test = []

# print "Accuracy\n", accuracy
# print "\nPrecision\n", prec
# print "\nRecall\n", recall
# print "\nMetrics\n", results
# print "\nMatrix\n", matrix

# print "\nMean Cross validation Precision score", np.mean(pd.Series(prec))
# print "\nMean Cross validation Recall score", np.mean(pd.Series(recall))
# print "\nMean Cross validation Accuracy score", np.mean(pd.Series(accuracy))

# # print "\nPickling stuff..."
# # createPickle(accuracy, 'accuracy.pkl')
# # createPickle(prec, 'prec.pkl')
# # createPickle(results, 'results.pkl')
# # createPickle(matrix, 'matrix.pkl')
# # createPickle(Dest, 'Dest.pkl')
# # createPickle(Origin, 'Origin.pkl')
# # createPickle(UniqueCarrier, 'UniqueCarrier.pkl')
# # createPickle(TailNum, 'TailNum.pkl')
